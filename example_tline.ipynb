# %%
# %matplotlib inline
import pyvna as vna
vna.init(port='/dev/ttyUSB0', name='tiny')
# Out:
# 'FW Tiny V1.0 - 22 June 2014'

# %%
vna.temperature()
# Out:
# 46.6

# %%
vna.version()
# Out:
# 'FW Tiny V1.0 - 22 June 2014'

# %%
cal = vna.create()

# %%
gm = vna.cal_open(cal)
vna.polar(gm)
vna.bode(gm)
# Out:
# [============================================================] 2000 / 2000 points (reflection)
# [============================================================] 2000 / 2000 points (reflection)
# [============================================================] 2000 / 2000 points (reflection)

# %%
gm = vna.cal_short(cal)
vna.polar(gm)
vna.bode(gm)
# Out:
# [============================================================] 2000 / 2000 points (reflection)
# [============================================================] 2000 / 2000 points (reflection)
# [============================================================] 2000 / 2000 points (reflection)

# %%
gm = vna.cal_load(cal)
vna.polar(gm)
vna.bode(gm)
# Out:
# [============================================================] 2000 / 2000 points (reflection)
# [============================================================] 2000 / 2000 points (reflection)
# [============================================================] 2000 / 2000 points (reflection)

# %%
gm = vna.return_loss(cal)
vna.polar(gm)
vna.cartesian(gm)
y = vna.to_admittance(gm)
z = vna.to_impedance(gm)
xp = vna.to_parallel(gm)
vna.cartesian(z)
vna.cartesian(y)
vna.cartesian(xp)
vna.plot(z)
vna.plot(vna.to_inductance(z))
vna.plot(vna.to_capacitance(z))
vna.plot(y)
vna.plot(xp)
vna.plot(vna.to_inductance(xp))
vna.plot(vna.to_capacitance(xp))
vna.bode(gm)
# Out:
# [============================================================] 2000 / 2000 points (reflection)
# [============================================================] 2000 / 2000 points (reflection)
# [============================================================] 2000 / 2000 points (reflection)
